# %%
import socket
import signal
import threading
from concurrent.futures import ThreadPoolExecutor
import time
from collections import namedtuple
import ssl 
import os
from subprocess import Popen, PIPE
import email.utils as eut
import datetime
import logging
import sys

# %%
# Create logger
logger = logging.getLogger()
logger.setLevel(logging.DEBUG)
# Create STDERR handler
handler = logging.StreamHandler(sys.stderr)

# Create formatter and add it to the handler
formatter = logging.Formatter('%(asctime)s: %(message)s')
handler.setFormatter(formatter)

# Set STDERR handler as the only handler 
logger.handlers = [handler]

# %%
Config = namedtuple('config', 'LISTENNQ MAX_REQUEST_LEN socket, timeout')
config = Config(LISTENNQ=10, MAX_REQUEST_LEN=1024, socket=('', 12345), timeout = 10.0)
terminator = b'\r\n\r\n'
newline = '\r\n'
newlineB = newline.encode()
# blackList = ['sing.cse.ust.hk']
blackList= []

# %% [markdown]
# ### SSL Cert

# %%
def join_with_script_dir(path):
    root = !pwd
    return os.path.join(root[0], path)

certdir = join_with_script_dir('certs/')
cakey = join_with_script_dir('ca.key')
cacert = join_with_script_dir('ca.crt')
certkey = join_with_script_dir('cert.key')

# %%
def send_cacert(conn):
    with open(cacert, 'rb') as f:
        data = f.read()
    response = '''HTTP/1.1 200 OK\r
Content-Type: application/x-x509-ca-cert\r
Content-Length: %d\r
Connection: close\r
\r\n'''%(len(data))
    response = response.encode('utf8')
    payload = response + data
    sendAll(conn, payload)
    
def createCert(certpath, target):
    epoch = "%d" % (time.time() * 1000)
    p1 = Popen(["openssl", "req", "-new", "-key", certkey, "-subj", "/CN=%s" % target], stdout=PIPE)
    p2 = Popen(["openssl", "x509", "-req", "-days", "3650", "-CA", cacert, "-CAkey", cakey, "-set_serial", epoch, "-out", certpath], stdin=p1.stdout, stderr=PIPE)
    p2.communicate()

# %% [markdown]
# ## http class

# %%
class httpHeader():
    def __init__(self, msg):
        msg = msg.strip(terminator).decode().split(newline)
        self.firstLine = msg[0].split(' ')
        header = msg[1:]
        tags = {}
        for row in header:
            field = row.split(':')
            key = field[0].strip().lower()
            value = ':'.join(field[1:]).strip()
            if key in tags:
                tags[key] = "%s, %s"%(tags[key], value)
            else:
                tags[key] = value
        self.fields = tags
    
    def get(self, key, notFind =None):
        return self.fields.get(key.lower(), notFind)
    
    def appendField(self, tag, value):
        pos = self.raw.find(tag.encode())
        if pos != -1:
            end = self.raw.find(newlineB, pos)
            line = ("%s: %s"%(tag, value)).encode()
            self.raw = self.raw[:pos] + line + self.raw[end:]
        else:
            headerEnd = self.raw.find(terminator)
            line = ("%s%s: %s"%(newline, tag, value)).encode()
            self.raw = self.raw[:headerEnd] + line + self.raw[headerEnd:]
        
class responseHeader(httpHeader):
    def __init__(self, msg):
        self.raw = msg #in bytes
        msg = msg.split(terminator)
        httpHeader.__init__(self, msg[0])
        if not self.firstLine[0].startswith('HTTP'):
            raise RuntimeError('receive invalid response')
        self.protocol = self.firstLine[0]
        self.statusCode = self.firstLine[1]
        self.statusMessage = ' '.join(self.firstLine[2:])
        
    def resetAge(self):
        self.startTime = datetime.datetime.now()
                
    def setLifeTime(self):
        self.startTime = datetime.datetime.now()
        if hasattr(self, 'lifeTime'):
            return True
        control = self.get('Cache-control', False)
        if control and 'max-age' in control:
            pos = control.find('max-age')
            end = control.find(',',pos)
            end = None if end == -1 else end
            self.lifeTime = int(control[pos+8:end])
            return True
        expire = self.get('Expires', False)
        date =self.get('Date', False)
        if expire and date:
            e = eut.parsedate_to_datetime(expire)
            d = eut.parsedate_to_datetime(date)
            delta = e - d
            self.lifeTime = delta.total_seconds()
            return True
        modified = self.get('Last-Modified', False)
        if modified:
            mo = eut.parsedate_to_datetime(modified)
            d = eut.parsedate_to_datetime(date)
            delta = d - mo
            self.lifeTime = delta.total_seconds() / 10
            return True
        if control and any(i in control for i in ['immutable', 'public']):
            self.lifeTime = 60000
            return True
        
        return False
    
    def checkIfFresh(self):
        age = int((datetime.datetime.now() - self.startTime).total_seconds())
        if age >= self.lifeTime:
            return False
        return age
    
class requestHeader(httpHeader):
    def __init__(self, msg):
        self.raw = msg #in bytes
        msg = msg.split(terminator)
        httpHeader.__init__(self, msg[0])
        if not self.firstLine[-1].startswith('HTTP'):
            raise RuntimeError('receive invalid response')
        self.method = self.firstLine[0]
        self.link = self.firstLine[1]
        self.protocol = self.firstLine[2]
        self._parseHost()
        
    def _parseHost(self):
        url = self.get('Host')
        portNo = url.find(':')
        if portNo == -1:
            port = 80
            webserver = url
        else:
            port = int(url[portNo+1:])
            webserver = url[:portNo]
        self.target = webserver; self.port = port
        
    def replaceRelative(self):
        url = self.link.encode()
        newUrl = url.replace(b'http://', b'')
        pathPos = newUrl.find(b'/')
        if pathPos == -1:
            self.link = '/'
            self.raw = self.raw.replace(url, b'/', 1)
        else:
            self.link = newUrl[pathPos:].decode()
            self.raw = self.raw.replace(url, newUrl[pathPos:], 1)

# %% [markdown]
# ## Cache

# %%
def cacheable(request, response):
    rqCache = request.get('Cache-Control',[])
    rpCache = response.get('Cache-Control',[])
    noCache = ['no-store', 'private']
    for c in [rqCache,rpCache]:
        if any(xs in c for xs in noCache):
            return False
    authButOk = ["must-revalidate", "public", "s-maxage"]
    if request.get('Authorization', False):
        return any(xs in rpCache for xs in authButOk)
    other = ["s-maxage", 'max-age', 'public']
    if response.get('Expires', False) or \
        response.get('Etag', False) or \
        any(xs in rpCache for xs in other):
        return True
    return False 

class Cache():
    def __init__(self):
        self.cacheData = {}
    
    def storeResponse(self, request, response):
        if cacheable(request, response) and response.setLifeTime():
            pKey = request.link
            host = request.target
            vary = response.get('Vary', False)
            self.cacheData[host] = self.cacheData.get(host, {})
            if vary:
                vary = vary.split(',')
                conditions = []
                for v in vary:
                    v = v.strip()
                    tryGet = request.get(v, False)
                    if not tryGet:
                        tryGet = response.get(v, False)
                        if not tryGet:
                            return
                    conditions.append((v, tryGet))
                conditions = tuple(conditions)
                self.cacheData[host][pKey] = self.cacheData[host].get(pKey, {})
                self.cacheData[host][pKey][conditions] = response
            else:
                self.cacheData[host][pKey] = response
            logger.info("%s %s cached"%(host, pKey))
            
    def searchCache(self, request):
        if len(self.cacheData) == 0:
            return False, False
        out = None
        target = self.cacheData.get(request.target, {}).get(request.link,False)
        if target == False :
            return False, False
        if type(target) == responseHeader:
            out = target
        else:
            for vary, response in target.items():
                same = True
                for condition in vary: #check every conditions in vary
                    require = request.get(condition[0], False)
                    if not require or require != condition[1]:
                        same = False
                        break
                if same:
                    out = response
                    break
        if type(out) != responseHeader:
            return False, False
        age = out.checkIfFresh()
        if age: #fresh
            re = ['no-cache', 'revalidate']
            control = request.get('Cache-Control','')
            if any(xs in control for xs in re):
                return out, True #revalidate
            else:
                out.appendField("Age", age)
                return out, False
        else: # check with server
            return out, True
        
    def updateCache(self, request, response, oldCache):
        if response.statusCode == '304' and \
                'Not Modified' in response.statusMessage:
            oldCache.resetAge()
            oldCache.appendField("Age", 0)
            logger.info('renew Cache with 304')
        elif response.statusCode == '200' and \
                'OK' in response.statusMessage and \
                response.setLifeTime():
            self.storeResponse(request, response)
            response.appendField("Age", 0)
            oldCache = response
            logger.info('renew Cache with 200')
        return oldCache

# %%
def constructValidate(request, cacheContent):
    etag = cacheContent.get('Etag', False)
    if etag:
        request.appendField('If-None-Match', etag)
    last = cacheContent.get('Last-Modified', False)
    if last:
        request.appendField('If-Modified-Since', last)

# %%
def createResponse(protocol, statusCode):
    protocol = protocol.encode()
    if statusCode == 200:
        return b'%s 200 Connection Established%s'%(protocol, terminator)
    elif statusCode == 408:
        return b"%s 408 Request Timeout%s"%(protocol, terminator)
    elif statusCode == 404:
        return b"%s 404 Not Found%s"%(protocol, terminator)

# %%
class end(Exception): pass

# %%
def sendAll(sock, msg):
    totalsent = 0
    while totalsent < len(msg):
        sent = sock.send(msg[totalsent:])
        if sent == 0:
            raise RuntimeError("socket connection broken")
        totalsent = totalsent + sent
    return totalsent
        
def readSocket(sock):
    buffer = b''
    while 1:
        data = sock.recv(config.MAX_REQUEST_LEN)
        if len(data) == 0:
            return buffer, True
        buffer += data
        if terminator in buffer:    #check end
            bufferSplit = buffer.split(terminator)
            header = bufferSplit[0]
            body = terminator.join(bufferSplit[1:])
            headerDetail = httpHeader(header)
            encoding = headerDetail.get('Transfer-Encoding',-1)
            length = headerDetail.get('Content-Length',-1)
            if (encoding == -1 and length == -1) or \
                (encoding == 'chunked' and b'0\r\n\r\n' in body) or \
                int(length) == len(body):
                    return buffer, False
                
#receive connect request from client
def handleRequest(conn):
    (clientSocket, client_address) = conn
    clientSocket.settimeout(config.timeout)
    buffer = b''
    while 1:
        try:
            request = clientSocket.recv(config.MAX_REQUEST_LEN)
            buffer += request
            if terminator in request:
                break
            elif len(request) == 0:
                raise RuntimeError("client close connection during init")
        except ConnectionResetError as e:
            raise RuntimeError("Connection Reset Error")
        except socket.timeout as t:
            sendAll(clientSocket, createResponse("HTTP/1.1", 408))
            raise RuntimeError("Client request timeout")
    request = requestHeader(buffer)
    try:
    ##########special cases#################
        if request.target in blackList:
            response = createResponse(request.protocol, 404)
            sendAll(clientSocket, response)
            raise end()
        if request.target == 'www.proxy.test':
            send_cacert(clientSocket)
            raise end()
        ########################################
        redirect(clientSocket, request)
    except end:
        pass
    clientSocket.close()

#redirect following request and response to and from client
def redirect(conn, request):
    s = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
    s.settimeout(config.timeout)
    conn.settimeout(config.timeout)
    https = request.method == 'CONNECT'
    if https:
        context = ssl.create_default_context()
        s = context.wrap_socket(s, server_hostname=request.target) #ssl connection with real server
        s.connect((request.target, request.port))
        sendAll(conn, createResponse("HTTP/1.1", 200))
        certpath = "%s/%s.crt" % (certdir.rstrip('/'), request.target)
        if not os.path.isfile(certpath): #create self-signed cert
            createCert(certpath, request.target)
        conn = ssl.wrap_socket(conn, keyfile=certkey, certfile=certpath, server_side=True) # ssl connection with client
    else:
        s.connect((request.target, request.port))
    first = True; endOfClientSocket = False; endOfServerSocket = False
    while 1:
        try:
            if https or not first:
                request, endOfClientSocket = readSocket(conn) #read client request
                request = requestHeader(request)
            if not https:
                request.replaceRelative()
            ###################Search Cache#######################
            tryCache, needValidate = cache.searchCache(request)
            if tryCache: #cache found
                if needValidate:
                    constructValidate(request, tryCache)
                    sendAll(s, request.raw)
                    update, endOfServerSocket = readSocket(s)
                    update = responseHeader(update)
                    tryCache = cache.updateCache(request, update, tryCache)
                sendAll(conn, tryCache.raw)
                logger.info("%s %s reply with cache"%(request.target, request.link))
                first = False
                if endOfServerSocket:
                    break
                continue
            sendAll(s, request.raw)
            if endOfClientSocket:
                break
            #######################################################
            response, endOfServerSocket = readSocket(s) # read server response
            sendAll(conn, response)
            ###################Cache############################
            if request.method == 'GET':
                response = responseHeader(response)
                if '200' in response.statusCode:
                    cache.storeResponse(request, response)
            ####################################################
            if endOfServerSocket:
                break
            first = False
        except socket.timeout:
            logger.info('Timeout')
            break
    s.close()

# %%
class Server():
    def __init__(self, config):
        signal.signal(signal.SIGINT, self.shutdown) 
        self.serverSocket = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
        self.serverSocket.setsockopt(socket.SOL_SOCKET, socket.SO_REUSEADDR, 1)
        self.serverSocket.bind(config.socket)
        self.serverSocket.listen(config.LISTENNQ)
        self.jobs = []
    
    def shutdown(self):
        for job in self.jobs:
            while not job.done():
                pass
        self.serverSocket.shutdown(socket.SHUT_RDWR)
        self.serverSocket.close()

# %%
executor = ThreadPoolExecutor(config.LISTENNQ)

# %%
server = Server(config)

# %%
cache = Cache()

# %%
server.shutdown()

# %%
while True:
    conn,addr = server.serverSocket.accept()
    server.jobs.append(executor.submit(handleRequest, (conn, addr)))
# while True:
#     conn,addr = server.serverSocket.accept()
#     handleRequest((conn, addr))
server.shutdown()
# Out:
# 2019-05-24 14:00:51,184: sing.cse.ust.hk /themes/default/style.css cached
# 2019-05-24 14:00:51,187: sing.cse.ust.hk /themes/default/scripts/unslider.min.js cached
# 2019-05-24 14:00:51,198: sing.cse.ust.hk /themes/default/scripts/modernizr-2.6.1.min.js cached
# 2019-05-24 14:00:51,249: sing.cse.ust.hk /themes/default/fonts/cJZKeOuBrn4kERxqtaUH3SZ2oysoEQEeKwjgmXLRnTc.ttf cached
# 2019-05-24 14:00:51,270: sing.cse.ust.hk /themes/default/img/SING-white.svg cached
# 2019-05-24 14:00:51,288: sing.cse.ust.hk /themes/default/img/footer-logo.svg cached
# 2019-05-24 14:00:51,308: sing.cse.ust.hk /themes/default/img/welcome-2.jpg cached
# 2019-05-24 14:00:51,349: sing.cse.ust.hk /themes/default/img/testbed.jpg cached
# 2019-05-24 14:00:51,353: sing.cse.ust.hk /themes/default/fonts/k3k702ZOKiLJc3WVjuplzJS3E-kSBmtLoNJPDtbj2Pk.ttf cached
# 2019-05-24 14:00:51,560: sing.cse.ust.hk /themes/default/favicon.ico cached
# 2019-05-24 14:00:52,491: adblocker.pcvark.com /firefox/adblocker-firefoxImportjs.js cached
# 2019-05-24 14:00:59,175: renew Cache with 304
# 2019-05-24 14:00:59,177: sing.cse.ust.hk /themes/default/style.css reply with cache
# 2019-05-24 14:00:59,177: renew Cache with 304
# 2019-05-24 14:00:59,178: renew Cache with 304
# 2019-05-24 14:00:59,179: sing.cse.ust.hk /themes/default/scripts/modernizr-2.6.1.min.js reply with cache
# 2019-05-24 14:00:59,180: sing.cse.ust.hk /themes/default/scripts/unslider.min.js reply with cache
# 2019-05-24 14:00:59,225: renew Cache with 304
# 2019-05-24 14:00:59,225: renew Cache with 304
# 2019-05-24 14:00:59,226: sing.cse.ust.hk /themes/default/fonts/cJZKeOuBrn4kERxqtaUH3SZ2oysoEQEeKwjgmXLRnTc.ttf reply with cache
# 2019-05-24 14:00:59,226: renew Cache with 304
# 2019-05-24 14:00:59,227: renew Cache with 304
# 2019-05-24 14:00:59,229: sing.cse.ust.hk /themes/default/img/SING-white.svg reply with cache
# 2019-05-24 14:00:59,231: renew Cache with 304
# 2019-05-24 14:00:59,233: renew Cache with 304
# 2019-05-24 14:00:59,233: sing.cse.ust.hk /themes/default/img/welcome-2.jpg reply with cache
# 2019-05-24 14:00:59,235: sing.cse.ust.hk /themes/default/img/testbed.jpg reply with cache
# 2019-05-24 14:00:59,236: sing.cse.ust.hk /themes/default/img/footer-logo.svg reply with cache
# 2019-05-24 14:00:59,237: sing.cse.ust.hk /themes/default/fonts/k3k702ZOKiLJc3WVjuplzJS3E-kSBmtLoNJPDtbj2Pk.ttf reply with cache
# 2019-05-24 14:00:59,483: renew Cache with 304
# 2019-05-24 14:00:59,484: sing.cse.ust.hk /themes/default/favicon.ico reply with cache
# 2019-05-24 14:00:59,512: renew Cache with 304
# 2019-05-24 14:00:59,512: adblocker.pcvark.com /firefox/adblocker-firefoxImportjs.js reply with cache
# 2019-05-24 14:01:09,245: Timeout
# 2019-05-24 14:01:09,247: Timeout
# 2019-05-24 14:01:09,247: Timeout
# 2019-05-24 14:01:09,248: Timeout
# 2019-05-24 14:01:09,248: Timeout
# 2019-05-24 14:01:09,523: Timeout
# 2019-05-24 14:01:09,563: sing.cse.ust.hk /themes/default/style.css reply with cache
# 2019-05-24 14:01:09,566: sing.cse.ust.hk /themes/default/scripts/modernizr-2.6.1.min.js reply with cache
# 2019-05-24 14:01:09,602: sing.cse.ust.hk /themes/default/scripts/unslider.min.js reply with cache
# 2019-05-24 14:01:09,626: sing.cse.ust.hk /themes/default/img/SING-white.svg reply with cache
# 2019-05-24 14:01:09,627: sing.cse.ust.hk /themes/default/img/welcome-2.jpg reply with cache
# 2019-05-24 14:01:09,628: sing.cse.ust.hk /themes/default/img/footer-logo.svg reply with cache
# 2019-05-24 14:01:09,633: sing.cse.ust.hk /themes/default/img/testbed.jpg reply with cache
# 2019-05-24 14:01:10,375: adblocker.pcvark.com /firefox/adblocker-firefoxImportjs.js reply with cache
# 2019-05-24 14:01:14,343: sing.cse.ust.hk /themes/default/style.css reply with cache
# 2019-05-24 14:01:14,345: sing.cse.ust.hk /themes/default/scripts/modernizr-2.6.1.min.js reply with cache
# 2019-05-24 14:01:14,345: sing.cse.ust.hk /themes/default/scripts/unslider.min.js reply with cache
# 2019-05-24 14:01:14,385: sing.cse.ust.hk /themes/default/img/SING-white.svg reply with cache
# 2019-05-24 14:01:14,385: sing.cse.ust.hk /themes/default/img/welcome-2.jpg reply with cache
# 2019-05-24 14:01:14,387: sing.cse.ust.hk /themes/default/img/testbed.jpg reply with cache
# 2019-05-24 14:01:14,387: sing.cse.ust.hk /themes/default/img/footer-logo.svg reply with cache
# 2019-05-24 14:01:14,454: adblocker.pcvark.com /firefox/adblocker-firefoxImportjs.js reply with cache
# 2019-05-24 14:01:17,987: sing.cse.ust.hk /themes/default/scripts/unslider.min.js reply with cache
# 2019-05-24 14:01:17,987: sing.cse.ust.hk /themes/default/style.css reply with cache
# 2019-05-24 14:01:17,988: sing.cse.ust.hk /themes/default/scripts/modernizr-2.6.1.min.js reply with cache
# 2019-05-24 14:01:18,049: sing.cse.ust.hk /themes/default/img/SING-white.svg reply with cache
# 2019-05-24 14:01:18,049: sing.cse.ust.hk /themes/default/img/welcome-2.jpg reply with cache
# 2019-05-24 14:01:18,049: sing.cse.ust.hk /themes/default/img/testbed.jpg reply with cache
# 2019-05-24 14:01:18,053: sing.cse.ust.hk /themes/default/img/footer-logo.svg reply with cache
# 2019-05-24 14:01:18,147: adblocker.pcvark.com /firefox/adblocker-firefoxImportjs.js reply with cache
# 2019-05-24 14:01:28,059: Timeout
# 2019-05-24 14:01:28,060: Timeout
# 2019-05-24 14:01:28,062: Timeout
# 2019-05-24 14:01:28,154: Timeout
# 2019-05-24 14:01:28,316: renew Cache with 304
# 2019-05-24 14:01:28,317: sing.cse.ust.hk /themes/default/style.css reply with cache
# 2019-05-24 14:01:28,320: renew Cache with 304
# 2019-05-24 14:01:28,321: renew Cache with 304
# 2019-05-24 14:01:28,321: sing.cse.ust.hk /themes/default/scripts/modernizr-2.6.1.min.js reply with cache
# 2019-05-24 14:01:28,321: sing.cse.ust.hk /themes/default/scripts/unslider.min.js reply with cache
# 2019-05-24 14:01:28,364: renew Cache with 304
# 2019-05-24 14:01:28,364: sing.cse.ust.hk /themes/default/fonts/cJZKeOuBrn4kERxqtaUH3SZ2oysoEQEeKwjgmXLRnTc.ttf reply with cache
# 2019-05-24 14:01:28,380: renew Cache with 304
# 2019-05-24 14:01:28,381: renew Cache with 304
# 2019-05-24 14:01:28,381: renew Cache with 304
# 2019-05-24 14:01:28,382: sing.cse.ust.hk /themes/default/img/SING-white.svg reply with cache
# 2019-05-24 14:01:28,383: sing.cse.ust.hk /themes/default/img/testbed.jpg reply with cache
# 2019-05-24 14:01:28,383: renew Cache with 304
# 2019-05-24 14:01:28,384: renew Cache with 304
# 2019-05-24 14:01:28,384: sing.cse.ust.hk /themes/default/img/welcome-2.jpg reply with cache
# 2019-05-24 14:01:28,386: sing.cse.ust.hk /themes/default/fonts/k3k702ZOKiLJc3WVjuplzJS3E-kSBmtLoNJPDtbj2Pk.ttf reply with cache
# 2019-05-24 14:01:28,386: sing.cse.ust.hk /themes/default/img/footer-logo.svg reply with cache
# 2019-05-24 14:01:28,578: renew Cache with 304
# 2019-05-24 14:01:28,579: sing.cse.ust.hk /themes/default/favicon.ico reply with cache
# 2019-05-24 14:01:29,573: renew Cache with 304
# 2019-05-24 14:01:29,576: adblocker.pcvark.com /firefox/adblocker-firefoxImportjs.js reply with cache
# 2019-05-24 14:01:38,395: Timeout
# 2019-05-24 14:01:38,397: Timeout
# 2019-05-24 14:01:38,398: Timeout
# 2019-05-24 14:01:38,398: Timeout
# 2019-05-24 14:01:38,590: Timeout
# 2019-05-24 14:01:39,588: Timeout

# %%
server.jobs[0].result()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-9b38977c7dd2> in <module>
# ----> 1 server.jobs[0].result()
#
# ~/anaconda3/lib/python3.7/concurrent/futures/_base.py in result(self, timeout)
#     423                 raise CancelledError()
#     424             elif self._state == FINISHED:
# --> 425                 return self.__get_result()
#     426
#     427             self._condition.wait(timeout)
#
# ~/anaconda3/lib/python3.7/concurrent/futures/_base.py in __get_result(self)
#     382     def __get_result(self):
#     383         if self._exception:
# --> 384             raise self._exception
#     385         else:
#     386             return self._result
#
# ~/anaconda3/lib/python3.7/concurrent/futures/thread.py in run(self)
#      55
#      56         try:
# ---> 57             result = self.fn(*self.args, **self.kwargs)
#      58         except BaseException as exc:
#      59             self.future.set_exception(exc)
#
# <ipython-input-21-0d2249909726> in handleRequest(conn)
#      56             raise end()
#      57         ########################################
# ---> 58         redirect(clientSocket, request)
#      59     except end:
#      60         pass
#
# <ipython-input-21-0d2249909726> in redirect(conn, request)
#     108             sendAll(conn, response)
#     109             ###################Cache############################
# --> 110             if request.method == 'GET' and '200' in response.statusMessage:
#     111                 response = responseHeader(response)
#     112                 cache.storeResponse(request, response)
#
# AttributeError: 'bytes' object has no attribute 'statusMessage'

# %%
request =b'''GET / HTTP/1.1\r
Host: example.com\r
User-Agent: Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:67.0) Gecko/20100101 Firefox/67.0\r
Accept: text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8\r
Accept-Language: en-US,en;q=0.5\r
Accept-Encoding: gzip, deflate, br\r
Connection: keep-alive\r
Upgrade-Insecure-Requests: 1\r
If-Modified-Since: Fri, 09 Aug 2013 23:54:35 GMT\r
If-None-Match: "1541025663"\r
Cache-Control: max-age=0\r
Cache-Control:s\r\n\r\n'''

# %%
cache.cacheData
# Out:
# {'sing.cse.ust.hk': {'/themes/default/style.css': <__main__.responseHeader at 0x7f3aa00bb6a0>,
#   '/themes/default/scripts/unslider.min.js': <__main__.responseHeader at 0x7f3aa00bb668>,
#   '/themes/default/scripts/modernizr-2.6.1.min.js': <__main__.responseHeader at 0x7f3aa00cfb38>,
#   '/themes/default/img/SING-white.svg': <__main__.responseHeader at 0x7f3aa00cfda0>,
#   '/themes/default/img/testbed.jpg': <__main__.responseHeader at 0x7f3aa00cfe10>,
#   '/themes/default/img/welcome-2.jpg': <__main__.responseHeader at 0x7f3aa00d12b0>,
#   '/themes/default/img/footer-logo.svg': <__main__.responseHeader at 0x7f3aa0096b00>,
#   '/themes/default/favicon.ico': <__main__.responseHeader at 0x7f3aa00cf860>},
#  'adblocker.pcvark.com': {'/firefox/adblocker-firefoxImportjs.js': {(('Accept-Encoding',
#      'gzip, deflate, br'),): <__main__.responseHeader at 0x7f3aa0096d30>}}}
